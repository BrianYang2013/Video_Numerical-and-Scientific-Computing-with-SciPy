# %% [markdown]
# ## Code to solve numberically the Lorenz system

# %%
import numpy
from numpy import linspace
import scipy
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

sigma=10.0
b=8.0/3.0
r=28.0

f=lambda x,t: [sigma*(x[1]-x[0]),
               r*x[0]-x[1]-x[0]*x[2],
               x[0]*x[1]-b*x[2]]
t=linspace(0,20,2000);y0=[5.0,5.0,5.0]
solution=odeint(f,y0,t)
X=solution[:,0];Y=solution[:,1];Z=solution[:,2]

# %% [markdown]
# ## Code to plot the obtained result of the Lorenz system

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (10.0, 10.0)
theplot = plt.figure().gca(projection='3d')
theplot.plot(X,Y,Z)
theplot.set_xlabel('X')
theplot.set_ylabel('Y')
theplot.set_zlabel('Z')

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

theplot.set_title(r'Solution of the Lorenz system', fontsize=16, color='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/YANGB7/anaconda/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /Users/YANGB7/anaconda/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...
