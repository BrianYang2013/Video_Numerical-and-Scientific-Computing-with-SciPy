# %%
from IPython.core.display import HTML
css_file = '../../../style/style01.css'
HTML(open(css_file, "r").read())
# Out:
# <style>
#
# div#notebook, div.CodeMirror, div.output_area pre, div.output_wrapper, div.promp
# t {
#   font-family: 'Inconsolata', monospace !important;
#   font-size: 14px;
# }
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 850px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
# ...

# %%
from IPython.core.display import HTML

# %%
#%matplotlib inline
# %matplotlib notebook

# %% [markdown]
# > Content under [Creative Commons Attribution license CC-BY 4.0](http://creativecommons.org/licenses/by/4.0/), [code under MIT license (c)](http://en.wikipedia.org/wiki/MIT_License) 2016-2017 Sergio Rojas (srojas@usb.ve).

# %% [markdown]
# <b> <center>
# ### Scatter plots via  Matplotlib

# %%
import numpy as np
x  = np.array([1.5, 2.7, 3.8, 9.5,12.3])
y =  np.array([3.8,-2.4, 0.35,6.2,1.5])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)

ax.scatter(y, x, label='Scatter Plot 1')
ax.scatter(x, y, label='Scatter plot 2', s=500, c='red', marker='*')
ax.plot(2*x, 2*y, 'bo--', label='THIS Plot legend', lw=2, ms=10)

ax.set_title('THE TITLE LABEL', fontsize = 10)
ax.set_xlabel('THE HORIZONTAL (X-AXIS) LABEL', fontsize = 12)
ax.set_ylabel('THE VERTICAL (Y-AXIS) LABEL', fontsize = 15)
ax.legend(loc=4)
ax.xaxis.set_tick_params(labelsize=20)
ax.set_xticks([-4,5,14])
fig.savefig("fig0.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# <b> <center>
# ### Contour plots via  Matplotlib

# %%
x = []
y = []
z = []

filename = './Data_3D_ex_glass.dat'
with open(filename, 'r') as readingfile:
    for line in readingfile:
        data = line.strip().split()
        x.append(float(data[0]))
        y.append(float(data[1]))
        z.append(float(data[2]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-05575086ac83> in <module>()
#       4
#       5 filename = './Data_3D_ex_glass.dat'
# ----> 6 with open(filename, 'r') as readingfile:
#       7     for line in readingfile:
#       8         data = line.strip().split()
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data_3D_ex_glass.dat'

# %%
import numpy as np
nfilas  =  8 ; ncolums =  32 

X = np.array(x).reshape(nfilas,ncolums)
Y = np.array(y).reshape(nfilas,ncolums)
Z = np.array(z).reshape(nfilas,ncolums)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(1,2,1, projection='3d')
ax.scatter(X.flatten(), Y.flatten(), Z.flatten(), 'ob')

ax.set_xlabel('X',fontsize=16)
ax.set_ylabel('Y',fontsize=16)
ax.set_zlabel('Z',fontsize=16)
ax.set_title('Scatter plot of the surface',fontsize=16)

# THE CONTOUR PLOT IS GENERATED BELOW
ax = fig.add_subplot(1,2,2)
ax.contour(X, Y, Z)

ax.set_xlabel('X',fontsize=16)
ax.set_ylabel('Y',fontsize=16)
ax.set_title('Contours of the surface',fontsize=16)


fig.tight_layout()
fig.savefig("fig_chap_07_3Dfig_ex_2.png")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# <b> References </b>
#
# * ** [Matplotlib scatter plots](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter) **
#
# * ** [Matplotlib contour plots](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.contour) **

# %% [markdown]
# > Content under [Creative Commons Attribution license CC-BY 4.0](http://creativecommons.org/licenses/by/4.0/), [code under MIT license (c)](http://en.wikipedia.org/wiki/MIT_License) 2016-2017 Sergio Rojas (srojas@usb.ve)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(1,2,1, projection='3d')
ax.scatter(X.flatten(), Y.flatten(), Z.flatten(), 'ob')

ax.set_xlabel('X',fontsize=16)
ax.set_ylabel('Y',fontsize=16)
ax.set_zlabel('Z',fontsize=16)
ax.set_title('A view of a surface',fontsize=16)

#ax = fig.add_subplot(1,2,2, projection='3d')
ax = fig.add_subplot(1,2,2)
ax.contour(X, Y, Z, 5)

ax.set_xlabel('X',fontsize=16)
ax.set_ylabel('Y',fontsize=16)
#ax.set_zlabel('Z',fontsize=16)
ax.set_title('Another view of the surface',fontsize=16)


fig.tight_layout()
fig.savefig("fig_chap_07_3Dfig_ex_2.png")
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8, 6))
plt.scatter(y, x, label='THIS Plot legend')
plt.scatter(x, y, label='THIS other plot legend', s=500, c='red', marker='*')
plt.title('THE TITLE LABEL', fontsize = 10)
plt.xlabel('THE HORIZONTAL (X-AXIS) LABEL', fontsize = 12)
plt.ylabel('THE VERTICAL (Y-AXIS) LABEL', fontsize = 15)
plt.xticks([-4,5,14], fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(loc='best')
fig.savefig("fig0.png")
plt.show()

# %%
import numpy as np
import matplotlib.cm as cm



(X, Y) = np.mgrid[-2:2.1:0.2,-2:2.1:0.2]
Z = np.exp(4*X**2 + Y**2)

(y, x) = np.mgrid[-2:2.1:0.2,-2:2.1:0.2]
z = x * np.exp(-x ** 2 - y ** 2)
z = np.exp(-x ** 2 - y ** 2)
z = np.exp(-4*x**2 - 4*y**2)


fig = plt.figure()
plt.contour(x, y, z, 10)
plt.show()
